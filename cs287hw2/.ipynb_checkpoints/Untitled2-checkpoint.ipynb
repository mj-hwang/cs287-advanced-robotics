# %%
import os
import numpy as np
from skimage.transform import resize
import matplotlib.pyplot as plt
imnames = os.listdir("newhandle_robot")
# print(len(imnames))
# vids = os.listdir("human_vids")
# supposed_imnames = [str(i)+".png" for i in np.arange(1395)]

# %%
len(imnames)/20
# Out:
# 360.0

# %%
onedemo = [plt.imread("marvinData/"+str(i)+".png") for i in np.arange(30)]

# %%
demos = np.zeros((30,30,64,64,3))
for i in np.arange(0,900,30):
    for j in range(30):
#         resize(plt.imread(olddir+str(i+j)+"_real_A.png")[:,:,:3],(128,128))
        demos[i//30][j]=resize(plt.imread("marvinData/"+str(i+j)+".png")[:,:,:3],(64,64))

# %%
np.save("coffee_human_resized.npy",demos)

# %%
onedemo = demos[-1]
plt.imshow(np.hstack(onedemo[:5]))
plt.show()
plt.imshow(np.hstack(onedemo[5:10]))
plt.show()
plt.imshow(np.hstack(onedemo[10:15]))
plt.show()
plt.imshow(np.hstack(onedemo[15:20]))
plt.show()
plt.imshow(np.hstack(onedemo[20:25]))
plt.show()
plt.imshow(np.hstack(onedemo[25:30]))
plt.show()
# plt.imshow(np.hstack(onedemo[30:35]))
# plt.show()
# plt.imshow(np.hstack(onedemo[35:40]))
# plt.show()
# plt.imshow(np.hstack(onedemo[40:45]))
# plt.show()
onedemo
# Out:
# array([[[[0.87645036, 0.90779155, 0.93552081],
#          [0.87062913, 0.90494217, 0.93375333],
#          [0.85453019, 0.89029072, 0.9195108 ],
#          ...,
#          [0.88063441, 0.91923864, 0.92829245],
#          [0.86366794, 0.9004679 , 0.9098645 ],
#          [0.85225436, 0.89026415, 0.89989908]],
#
#         [[0.87509403, 0.90426496, 0.93060854],
#          [0.86434299, 0.89824469, 0.92670615],
#          [0.84757613, 0.88103783, 0.90875368],
#          ...,
#          [0.86678524, 0.89736569, 0.90220962],
#          [0.8542598 , 0.88811156, 0.89567406],
#          [0.84659173, 0.87847695, 0.88629305]],
#
#         [[0.87106864, 0.90501763, 0.93160985],
#          [0.85366231, 0.88866456, 0.91898514],
#          [0.84770711, 0.88070296, 0.90982319],
#          ...,
#          [0.76022199, 0.70175973, 0.64937918],
#          [0.76682979, 0.72015929, 0.67109607],
#          [0.76811768, 0.72013423, 0.67067151]],
#
#         ...,
#
# ...

# %%
len(imnames)
# Out:
# 24

# %%
len(vids)
# Out:
# 26

# %%
1560/26
# Out:
# 60.0

# %%
'8199.png' in imnames
# Out:
# False

# %%
'270.png' in imnames
# Out:
# False

# %%
dirname = "variedRobot/"
for i in np.arange(6400, 8200):
    old = dirname+str(i) + ".png "
    new = dirname+str(i-100) + ".png"
    os.system("scp "+ old + new)
#     print("scp "+ old + new)

# %%
setA = set(imnames)
setB = set(supposed_imnames)
setB.difference(setA)
# Out:
# set()

# %%
dirname = "variedRobot/"
for i in np.arange(8100, 8200):
    old = dirname+str(i) + ".png "
#     new = dirname+str(i-100) + ".png"
    os.system("rm "+ old)
#     print("rm "+ old)

# %%
1395/45
# Out:
# 31.0

# %%
os.listdir("redo_drawer_videos")
# Out:
# ['4_view0.mov',
#  '13_view0.mov',
#  '0_view0.mov',
#  '2_view0.mov',
#  '25_view0.mov',
#  '1_view0.mov',
#  '5_view0.mov',
#  '9_view0.mov',
#  '18_view0.mov',
#  '12_view0.mov',
#  '19_view0.mov',
#  '17_view0.mov',
#  '23_view0.mov',
#  '16_view0.mov',
#  '24_view0.mov',
#  '21_view0.mov',
#  '6_view0.mov',
#  '15_view0.mov',
#  '11_view0.mov',
#  '14_view0.mov',
#  '20_view0.mov',
#  '3_view0.mov',
#  '22_view0.mov',
#  '8_view0.mov',
#  '7_view0.mov',
#  '10_view0.mov']

# %%
os.listdir("human_vids")
# Out:
# ['121_view0.mov',
#  '144_view0.mov',
#  '139_view0.mov',
#  '140_view0.mov',
#  '133_view0.mov',
#  '143_view0.mov',
#  '123_view0.mov',
#  '126_view0.mov',
#  '142_view0.mov',
#  '136_view0.mov',
#  '125_view0.mov',
#  '132_view0.mov',
#  '128_view0.mov',
#  '127_view0.mov',
#  '131_view0.mov',
#  '135_view0.mov',
#  '122_view0.mov',
#  '138_view0.mov',
#  '129_view0.mov',
#  '141_view0.mov',
#  '124_view0.mov',
#  '145_view0.mov',
#  '120_view0.mov',
#  '134_view0.mov',
#  '137_view0.mov',
#  '130_view0.mov']
